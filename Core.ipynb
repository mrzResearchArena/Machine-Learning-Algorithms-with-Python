# %% [markdown]
# # Machine Learning ( with sci-kit learn )
# ## Author : **Rafsanjani Muhammod**

# %% [markdown]
# ### Core Basic Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
